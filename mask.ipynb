# %%
import torch
import matplotlib.pyplot as plt

# %%
img = torch.load("img.pt")
print(img.shape)
plt.imshow(img.squeeze().sum(0))
# Out:
# torch.Size([3, 224, 224])

# %%
orig = torch.load("orig.pt")
transformed = torch.load("transformed.pt")

# %%
plt.imshow(orig.sum(0))

# %%
plt.imshow(transformed.sum(0))

# %%
maskxexpl = torch.load("maskxexpl.pt")

# %%
plt.imshow(maskxexpl[0].squeeze())

len(torch.where(maskxexpl[0] == 0)[0])
# Out:
# 37703
