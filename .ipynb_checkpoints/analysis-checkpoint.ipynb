# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("results/20230202_pred_orig_eval_orig_transform_both/n02100236_390.JPEG_expl_InputXGrad_alpha_0.05_sample_1000_sigma_0.0_seed_0.npy", "rb") as f:
    orig_expl = np.load(f)
    conf_low = np.load(f)
    conf_high = np.load(f)

# %%
plt.imshow(orig_expl.squeeze(), cmap='bwr')
plt.colorbar()
plt.title("orig expl")

plt.clim(-0.3, 0.3)
plt.show()
plt.clf()

# %%
plt.imshow(conf_high.squeeze(), cmap='bwr')
plt.colorbar()
plt.title("conf high")
plt.clim(-0.3, 0.3)

plt.show()

# %%
plt.imshow(conf_low.squeeze(), cmap='bwr')
plt.colorbar()
plt.clim(-0.3, 0.3)

plt.title("conf low")
plt.show()
